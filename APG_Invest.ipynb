# %% [markdown]
# # Statistical Analysis
#
# ## 1. Basic Insights of the Dataset

# %%
# import pandas library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Amostra_STATA_R1.csv')

# %%
df.head(5)
# Out:
#    Years  Over_stay  Invest  Expend_Leis  Expend_Visit  Expend_Busin    GDP  \
# 0   2004      325.6    27.2         28.7          17.5          49.1  152.2
# 1   2005      338.2    23.6         25.5          19.8          31.4  158.6
# 2   2006      357.0    28.6         29.8          19.0          39.4  166.3
# 3   2007      376.9    31.8         25.4          18.6          68.3  175.5
# 4   2008      371.5    36.8         36.2          31.6          70.3  179.1
#
#    Disemb_Pass
# 0         11.0
# 1         11.4
# 2         12.3
# 3         13.4
# 4         13.8

# %%
print(df.columns)
# Out:
# Index(['Years', 'Over_stay', 'Invest', 'Expend_Leis', 'Expend_Visit',
#        'Expend_Busin', 'GDP', 'Disemb_Pass'],
#       dtype='object')

# %%
print(df.dtypes)
# Out:
# Years             int64
# Over_stay       float64
# Invest          float64
# Expend_Leis     float64
# Expend_Visit    float64
# Expend_Busin    float64
# GDP             float64
# Disemb_Pass     float64
# dtype: object

# %%
df.describe()
# This shows the statistical summary of all numeric-typed (int, float) columns.
# Out:
#              Years   Over_stay     Invest  Expend_Leis  Expend_Visit  \
# count    17.000000   17.000000  17.000000    17.000000     17.000000
# mean   2012.000000  436.100000  26.841176    31.182353     22.635294
# std       5.049752  129.351696   5.938546     7.122871      5.379700
# min    2004.000000  250.500000  18.500000    23.900000     16.500000
# 25%    2008.000000  353.600000  23.200000    25.500000     18.700000
# 50%    2012.000000  376.900000  26.000000    29.100000     20.100000
# 75%    2016.000000  512.400000  28.600000    35.700000     27.000000
# max    2020.000000  682.100000  40.600000    52.100000     33.500000
#
#        Expend_Busin         GDP  Disemb_Pass
# count     17.000000   17.000000    17.000000
# mean      45.988235  179.794118    17.041176
# std       20.456077   16.331850     6.219934
# min       18.800000  152.200000     9.100000
# 25%       32.500000  170.500000    13.400000
# 50%       39.900000  176.100000    15.200000
# 75%       49.600000  186.500000    19.700000
# max       99.900000  214.400000    30.000000

# %%
df[['GDP','Over_stay']].describe()
# Out:
#               GDP   Over_stay
# count   17.000000   17.000000
# mean   179.794118  436.100000
# std     16.331850  129.351696
# min    152.200000  250.500000
# 25%    170.500000  353.600000
# 50%    176.100000  376.900000
# 75%    186.500000  512.400000
# max    214.400000  682.100000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Years         17 non-null     int64
#  1   Over_stay     17 non-null     float64
#  2   Invest        17 non-null     float64
#  3   Expend_Leis   17 non-null     float64
#  4   Expend_Visit  17 non-null     float64
#  5   Expend_Busin  17 non-null     float64
#  6   GDP           17 non-null     float64
#  7   Disemb_Pass   17 non-null     float64
# dtypes: float64(7), int64(1)
# memory usage: 1.1 KB

# %%
#We use the following functions to identify these missing values.

missing_data = df.isnull()
missing_data.head(5)
# Out:
#    Years  Over_stay  Invest  Expend_Leis  Expend_Visit  Expend_Busin    GDP  \
# 0  False      False   False        False         False         False  False
# 1  False      False   False        False         False         False  False
# 2  False      False   False        False         False         False  False
# 3  False      False   False        False         False         False  False
# 4  False      False   False        False         False         False  False
#
#    Disemb_Pass
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False

# %%
#Count missing values in each column

for column in missing_data.columns.values.tolist():
    print(column)
    print (missing_data[column].value_counts())
    print("")
# Out:
# Years
# False    17
# Name: Years, dtype: int64
#
# Over_stay
# False    17
# Name: Over_stay, dtype: int64
#
# Invest
# False    17
# Name: Invest, dtype: int64
#
# Expend_Leis
# False    17
# Name: Expend_Leis, dtype: int64
#
# Expend_Visit
# False    17
# Name: Expend_Visit, dtype: int64
#
# Expend_Busin
# False    17
# Name: Expend_Busin, dtype: int64
#
# GDP
# False    17
# Name: GDP, dtype: int64
#
# Disemb_Pass
# False    17
# Name: Disemb_Pass, dtype: int64

# %%
#Calculate the mean value for the "GDP" column 
avg_pib = df["GDP"].astype("float").mean(axis=0)
print("GDP Average:", avg_pib)
# Out:
# GDP Average: 179.79411764705878

# %%
#To see which values are present in a particular column, we can use the ".value_counts()" method:
df['Over_stay'].value_counts()
# Out:
# 325.6    1
# 416.3    1
# 682.1    1
# 657.9    1
# 634.8    1
# 572.6    1
# 512.4    1
# 468.3    1
# 377.4    1
# 338.2    1
# 373.6    1
# 353.6    1
# 345.0    1
# 371.5    1
# 376.9    1
# 357.0    1
# 250.5    1
# Name: Over_stay, dtype: int64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df.plot(x="Years", y=["Invest"])

plt.show()

# %%
df.plot(x="Years", y=["Expend_Leis","Expend_Busin","Expend_Visit"])

plt.show()

# %%
df.corr()
# Out:
#                  Years  Over_stay    Invest  Expend_Leis  Expend_Visit  \
# Years         1.000000   0.620040  0.040849     0.219635      0.334055
# Over_stay     0.620040   1.000000 -0.260690     0.145144      0.249059
# Invest        0.040849  -0.260690  1.000000     0.546538      0.630809
# Expend_Leis   0.219635   0.145144  0.546538     1.000000      0.904858
# Expend_Visit  0.334055   0.249059  0.630809     0.904858      1.000000
# Expend_Busin -0.105157   0.084330  0.619101     0.817394      0.754189
# GDP           0.858703   0.658817  0.316990     0.440670      0.609300
# Disemb_Pass   0.668596   0.989478 -0.247122     0.188432      0.294080
#
#               Expend_Busin       GDP  Disemb_Pass
# Years            -0.105157  0.858703     0.668596
# Over_stay         0.084330  0.658817     0.989478
# Invest            0.619101  0.316990    -0.247122
# Expend_Leis       0.817394  0.440670     0.188432
# Expend_Visit      0.754189  0.609300     0.294080
# Expend_Busin      1.000000  0.236648     0.091881
# GDP               0.236648  1.000000     0.718245
# Disemb_Pass       0.091881  0.718245     1.000000

# %% [markdown]
# ### Multicollinearity:
#
# - overnight stay and passengers disembarked (99.0%);
# - leisure expenditure and visits expenditure (90.5%).

# %% [markdown]
# ## 2. Multiple Linear Regression

# %%
# Let's load the modules for linear regression:

from sklearn.linear_model import LinearRegression

# Create the linear regression object:
lm = LinearRegression()
lm
# Out:
# LinearRegression()

# %%
Z = df[['GDP', 'Over_stay', 'Expend_Leis', 'Expend_Visit', 'Expend_Busin', 'Disemb_Pass']]

# %%
lm.fit(Z, df['Invest'])
# Out:
# LinearRegression()

# %%
# What is the value of the intercept(a)?

lm.intercept_
# Out:
# -33.558228766409925

# %%
# What are the values of the coefficients (b1, b2, b3, b4)?

lm.coef_
# Out:
# array([ 0.35522056,  0.08199464, -0.28303107,  0.35307506,  0.15396531,
#        -2.66836038])

# %% [markdown]
# #### Given the coefficients of the variables, we've decided to remove overnight stay and leisure expenses.

# %%
df[['Expend_Visit','Expend_Busin','GDP', 'Disemb_Pass']].corr()
# Out:
#               Expend_Visit  Expend_Busin       GDP  Disemb_Pass
# Expend_Visit      1.000000      0.754189  0.609300     0.294080
# Expend_Busin      0.754189      1.000000  0.236648     0.091881
# GDP               0.609300      0.236648  1.000000     0.718245
# Disemb_Pass       0.294080      0.091881  0.718245     1.000000

# %% [markdown]
# #### Finally we have a better adjustment of the regression model.

# %%
df[['Invest','Expend_Visit','Expend_Busin','GDP', 'Disemb_Pass']].corr()
# Out:
#                 Invest  Expend_Visit  Expend_Busin       GDP  Disemb_Pass
# Invest        1.000000      0.630809      0.619101  0.316990    -0.247122
# Expend_Visit  0.630809      1.000000      0.754189  0.609300     0.294080
# Expend_Busin  0.619101      0.754189      1.000000  0.236648     0.091881
# GDP           0.316990      0.609300      0.236648  1.000000     0.718245
# Disemb_Pass  -0.247122      0.294080      0.091881  0.718245     1.000000

# %% [markdown]
# ### Final Econometric Model

# %%
Z = df[['GDP', 'Expend_Visit', 'Expend_Busin', 'Disemb_Pass']]

# %%
lm.fit(Z, df['Invest'])
# Out:
# LinearRegression()

# %% [markdown]
# ### Multiple linear regression model:
#
# invest = Bo + B1(Expend_Visit) + B2(Expend_Busin) + B3(GDP) + B4(Disemb_Pass) + Er
#
# - Bo: constant of the equation;
# - Er: statistical error of the equation.

# %%
# What is the value of the intercept(a)?

lm.intercept_
# Out:
# -20.218797371981694

# %%
# What is the value of the intercept(a)?

lm.intercept_
# Out:
# -20.218797371981694

# %%
# What are the values of the coefficients (b1, b2, b3, b4)?

lm.coef_
# Out:
# array([ 0.30471446,  0.01188053,  0.14374591, -0.85706718])

# %% [markdown]
# ## RLM Expression:
#
# invest = -20.2188 + 0.3047145* gdp - 0.8570672* Disemb_Pass  + 0.0118805* Expend_Visit + 0.1437459* Expend_Busin
